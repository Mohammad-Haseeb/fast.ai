# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammad-Haseeb/fast.ai/blob/main/fastAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision.all import URLs,untar_data

# %%
path = untar_data(URLs.PETS)

# %%
path.ls()
# Out:
# (#2) [Path('/root/.fastai/data/oxford-iiit-pet/images'),Path('/root/.fastai/data/oxford-iiit-pet/annotations')]

# %%
files = get_image_files(path/"images")
len(files)
# Out:
# 7390

# %%
files[0],files[6]
# Out:
# (Path('/root/.fastai/data/oxford-iiit-pet/images/Persian_15.jpg'),
#  Path('/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_140.jpg'))

# %%
def label_func(f): return f[0].isupper()

# %%
dls = ImageDataLoaders.from_name_func(path, files, label_func, item_tfms=Resize(224))

# %%
dls.show_batch()
